# %% [markdown]
# <a href="https://colab.research.google.com/github/zianaoyao-web/fa4programactivity/blob/main/fa4program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for x in range(1,21):
  if x % 2 == 0:
    continue
  print(x)

# %%
correct_password = "mustache.man"

while True:
    password = input("Enter password: ")

    if password == correct_password:
        print("Access Granted!")
        break
    else:
       print("Incorrected Password >:(")

# %%
for x in range(1, 11):
    if x == 4:
        continue
    if x == 6:
        pass
    if x == 8:
        break

    print(x)
